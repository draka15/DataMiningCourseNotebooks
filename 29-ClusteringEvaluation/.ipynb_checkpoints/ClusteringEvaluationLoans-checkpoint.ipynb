# %% [markdown]
# # Evaluation of Clustering Performance
# We search for the optimal number of clusters for the Iris data set using several measures for clustering evaluation. First, we load all the libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from time import time
from sklearn import metrics
from sklearn import datasets
from sklearn.cluster import KMeans
# %matplotlib inline

# %% [markdown]
# Next, we set the maximum value of k and the list of values of k that we will check.

# %%
random_state = 1234
max_k = 10
k_values = np.arange(2,max_k+1,1)

# %% [markdown]
# Load the Iris dataset

# %%
# import some data to play with
dataset = pd.read_csv('LoansNumerical.csv')

target = 'safe_loans'
features = dataset.columns[dataset.columns!=target]

# 
x = dataset[features]
y = dataset[target]

# %%
dataset.describe()
# Out:
#        sub_grade_num      short_emp  emp_length_num            dti  \
# count  122462.000000  122462.000000   122462.000000  122462.000000
# mean        0.597511       0.123377        6.373618      15.504442
# std         0.278943       0.328871        3.735303       7.495961
# min         0.200000       0.000000        0.000000       0.000000
# 25%         0.400000       0.000000        3.000000       9.890000
# 50%         0.600000       0.000000        6.000000      15.270000
# 75%         0.800000       0.000000       11.000000      20.850000
# max         1.000000       1.000000       11.000000      39.880000
#
#        payment_inc_ratio    delinq_2yrs  delinq_2yrs_zero  inq_last_6mths  \
# count      122462.000000  122462.000000     122462.000000   122462.000000
# mean            7.566317       0.211845          0.858144        0.979700
# std             4.121514       0.661020          0.348904        1.258867
# min             0.028895       0.000000          0.000000        0.000000
# 25%             4.366800       0.000000          1.000000        0.000000
# 50%             6.968625       0.000000          1.000000        1.000000
# 75%            10.217900       0.000000          1.000000        2.000000
# max            43.545600      29.000000          1.000000       33.000000
#
#        last_delinq_none  last_major_derog_none      ...             int_rate  \
# count     122462.000000          122462.000000      ...        122462.000000
# mean           0.588493               0.873757      ...            13.642497
# std            0.492109               0.332125      ...             4.391458
# min            0.000000               0.000000      ...             5.420000
# 25%            0.000000               1.000000      ...            10.620000
# 50%            1.000000               1.000000      ...            13.480000
# 75%            1.000000               1.000000      ...            16.290000
# max            1.000000               1.000000      ...            26.060000
#
#        total_rec_int    annual_inc    funded_amnt  funded_amnt_inv  \
# count  122462.000000  1.224620e+05  122462.000000    122462.000000
# mean     1697.163606  7.138282e+04   12744.445624     12511.236718
# std      1794.062713  5.839878e+04    7886.861593      7941.774515
# min         0.000000  1.896000e+03     500.000000         0.000000
# 25%       550.775000  4.416000e+04    6625.000000      6300.000000
# 50%      1137.550000  6.000000e+04   11000.000000     10500.000000
# 75%      2168.830000  8.500000e+04   17450.000000     17000.000000
# max     20758.200000  7.141778e+06   35000.000000     35000.000000
#
#          installment       num_term      grade_num      loan_amnt  \
# count  122462.000000  122462.000000  122462.000000  122462.000000
# mean      396.869141      40.861459       4.233305   12817.792254
# std       239.461992       9.645828       1.361462    7931.898196
# min        15.670000      36.000000       0.000000     500.000000
# 25%       216.230000      36.000000       3.000000    6725.000000
# 50%       348.180000      36.000000       4.000000   11000.000000
# 75%       522.030000      36.000000       5.000000   17600.000000
# max      1408.130000      60.000000       6.000000   35000.000000
#
#           safe_loans
# count  122462.000000
# mean        0.622381
# std         0.782718
# min        -1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
#
# [8 rows x 25 columns]

# %% [markdown]
# List of the measures we will check.

# %%
score_funcs = [
    metrics.adjusted_rand_score,
    metrics.adjusted_mutual_info_score,
    metrics.mutual_info_score,
    metrics.calinski_harabaz_score,
    metrics.fowlkes_mallows_score,
    metrics.homogeneity_completeness_v_measure,
    metrics.silhouette_score
]

# %% [markdown]
# For every value of k, we apply k-means clustering and then evaluate all the metrics.

# %%
### generate a list for every metric
scores = {}
for score_func in score_funcs:
    if score_func!=metrics.homogeneity_completeness_v_measure:
        scores[score_func.__name__] = []
scores['homogeneity'] = []
scores['completeness'] = []
scores['v_measure'] = []

for k in k_values:
    yp = KMeans(n_clusters=k, random_state=random_state).fit_predict(x)
    for score_func in score_funcs:
        if score_func == metrics.calinski_harabaz_score:
            scores[score_func.__name__].append(score_func(x,yp))
        elif score_func == metrics.silhouette_score:
            scores[score_func.__name__].append(score_func(x,yp))
        elif score_func == metrics.homogeneity_completeness_v_measure:
            h,c,v = score_func(y,yp)
            scores['homogeneity'].append(h)
            scores['completeness'].append(c)
            scores['v_measure'].append(v)
        else:
            scores[score_func.__name__].append(score_func(y, yp))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1ea0ccc0d2cd> in <module>()
#       1 ### generate a list for every metric
#       2 scores = {}
# ----> 3 for score_func in score_funcs:
#       4     if score_func!=metrics.homogeneity_completeness_v_measure:
#       5         scores[score_func.__name__] = []
#
# NameError: name 'score_funcs' is not defined

# %% [markdown]
# Plot all the metrics.

# %%
f, axarr = plt.subplots(2, 1)

plt.rcParams['figure.figsize'] = (40.0, 30.0)
font = {'family' : 'sans', 'size'   : 28}
plt.rc('font', **font)

for i,s in enumerate(scores):
    axarr[int(i/3),int(i%3)].set_xlim([1,max_k])
    axarr[int(i/3),int(i%3)].set_xticks(k_values)
    axarr[int(i/3),int(i%3)].set_title("Measure - "+s)
    axarr[int(i/3),int(i%3)].plot(k_values,scores[s])
